# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#Load stock and crypto price files
stock_data = "Resources/all_stock_data.csv"
crypto_data = "Resources/all_crypto_data.csv"

# Create stock price DataFrames
stock_df = pd.read_csv(stock_data)
stock_df['date'] =  pd.to_datetime(stock_df['date'])
stock_df['weekday'] = stock_df['date'].dt.weekday
stock_df.set_index('date', inplace=True, drop=True)

crypto_df = pd.read_csv(crypto_data) 
crypto_df['date'] =  pd.to_datetime(crypto_df['date'])
crypto_df['weekday'] = crypto_df['date'].dt.weekday
crypto_df.set_index('date', inplace=True, drop=True)

# Print data
crypto_df.head()
# Out:
#             close_btc  close_xrp  close_eth  close_ltc  close_eos  close_dash  \
# date
# 2017-01-01     995.44   0.006346       8.14       4.42        0.0       11.06
# 2017-01-02    1017.05   0.006312       8.33       4.54        0.0       11.62
# 2017-01-03    1033.30   0.006411       9.59       4.51        0.0       12.22
# 2017-01-04    1135.41   0.006410      10.88       4.42        0.0       15.49
# 2017-01-05     989.35   0.006276      10.20       4.16        0.0       13.63
#
#             weekday
# date
# 2017-01-01        6
# 2017-01-02        0
# 2017-01-03        1
# 2017-01-04        2
# 2017-01-05        3

# %%
wkly_crypto_df = crypto_df.loc[crypto_df['weekday'] == 1]
wkly_crypto_df.drop(columns='weekday', axis=1,inplace=True)
wkly_crypto_df.columns = ['BTC','XRP','ETH','LTC','EOS','DASH']
wkly_crypto_df = wkly_crypto_df.pct_change()
wkly_crypto_df.head(300)
# Out:
#                  BTC       XRP       ETH       LTC       EOS      DASH
# date
# 2017-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-01-10 -0.124775  0.063017  0.100104 -0.008869       NaN -0.004910
# 2017-01-17 -0.005208  0.002201 -0.038863 -0.129754       NaN  0.154605
# 2017-01-24 -0.006569 -0.048316  0.036489 -0.035990       NaN -0.000712
# 2017-01-31  0.080269 -0.013846  0.019029  0.072000       NaN  0.136137
# 2017-02-07  0.087075  0.000000  0.069094 -0.022388       NaN  0.055207
# 2017-02-14 -0.039274 -0.029641  0.135371 -0.033079       NaN  0.072533
# 2017-02-21  0.109774 -0.059486 -0.017692 -0.005263       NaN  0.156319
# 2017-02-28  0.062769 -0.047863  0.258418 -0.002646       NaN  0.554650
# 2017-03-07  0.036510  0.208259  0.176727  0.050398       NaN  0.400247
# 2017-03-14  0.008477 -0.050520  0.511370  0.053030       NaN  0.931072
# 2017-03-21 -0.098018  0.067293  0.493002 -0.019185       NaN  0.118486
# 2017-03-28 -0.068555  0.400293  0.177642  0.026895       NaN -0.106240
# 2017-04-04  0.093210  2.965445 -0.115821  1.135714       NaN -0.216975
# 2017-04-11  0.069165 -0.124373 -0.015530  0.076923       NaN -0.113199
# 2017-04-18 -0.012001 -0.010555  0.140375  0.144928       NaN  0.190570
# 2017-04-25  0.048272 -0.017373  0.004210  0.361664       NaN -0.017524
# 2018-09-25  0.014386  0.646082  0.051874  0.065556  0.071146 -0.005870
# 2018-10-02  0.013627 -0.016378  0.028330  0.031283  0.036900 -0.039907
# 2018-10-09  0.016293 -0.069700  0.009228 -0.011122  0.053381 -0.004942
# 2018-10-16 -0.007349 -0.006452 -0.075915 -0.081459 -0.059122 -0.085476
# 2018-10-23 -0.017139 -0.024298 -0.031015 -0.024119 -0.014363 -0.059253
# 2018-10-30 -0.024900 -0.042722 -0.036868 -0.067681 -0.063752 -0.011994
# 2018-11-06  0.027042  0.239964  0.119119  0.142537  0.124514  0.109907
# 2018-11-13 -0.021691 -0.073793 -0.059847 -0.117973 -0.084775 -0.041352
# 2018-11-20 -0.299307 -0.146846 -0.366631 -0.335289 -0.279773 -0.346797
# 2018-11-27 -0.139317 -0.170062 -0.157182 -0.052359 -0.199475 -0.151597
# 2018-12-04  0.032815 -0.029509 -0.003358 -0.005782 -0.190164 -0.056259
#
# [101 rows x 6 columns]

# %%
wkly_stock_df = stock_df.loc[stock_df['weekday'] == 1]
wkly_stock_df.drop(columns='weekday', axis=1,inplace=True)
wkly_stock_df.columns = ['AMD','NVDA','MU']
wkly_stock_df = wkly_stock_df.pct_change()
wkly_stock_df.head()
# Out:
#                  AMD      NVDA        MU
# date
# 2017-01-03       NaN       NaN       NaN
# 2017-01-10  0.000875  0.043721 -0.003104
# 2017-01-17 -0.141608 -0.050343 -0.032918
# 2017-01-24  0.063136  0.061517  0.051058
# 2017-01-31 -0.006705  0.017237  0.055142

# %%
# Chart Weekly Pct Change for Stocks
fig, ax = plt.subplots()
ax.grid(axis='y')
ax.set_title('Weekly Stock Price Change (%)')
ax.set_ylabel('Pct Change (%)')
ax.plot(wkly_stock_df)
plt.xticks(rotation=50)
fig.legend(['AMD','NVDA','MU'],bbox_to_anchor=(1.2, 1.0))
fig.tight_layout() 
plt.show()

# %%
# Chart Weekly Pct Change for Cryptos
fig, ax = plt.subplots()
ax.grid(axis='y')
ax.set_title('Weekly Crypto Price Change (%)')
ax.set_ylabel('Pct Change (%)')
ax.plot(wkly_crypto_df)
plt.xticks(rotation=50)
fig.legend(['BTC','XRP','ETH','LTC','EOS','DASH'],bbox_to_anchor=(1.2, 1.0))
fig.tight_layout() 
plt.show()

# %%
# Create a chart of selected stocks
fig, ax = plt.subplots()
ax.grid(axis='y')
ax.set_title('Daily Stock Prices')
ax.set_ylabel('Price (USD)')
ax.plot(stock_df['date'], stock_df['close_amd'], color='green', label='AMD')
ax.plot(stock_df['date'], stock_df['close_nvda'], color='orange',label='NVDA')
ax.plot(stock_df['date'], stock_df['close_mu'], color='lightblue',label='MU')
ax.tick_params(axis='y')
plt.xticks(rotation=50)
fig.legend(bbox_to_anchor=(1.2, 1.0))
fig.tight_layout()
